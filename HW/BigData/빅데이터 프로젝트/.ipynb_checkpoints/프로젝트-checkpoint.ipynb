# %%
import pandas as pd

# %%
# 참조용
df_raw1 = pd.read_csv("insu_code_sick.csv", engine = "python", encoding="CP949")
df_raw1.tail()
# Out:
#       sick_cd_3 sick_cd_4          sick_desc_kor  \
# 13750       Z99      Z991                호흡기에 의존
# 13751       Z99      Z992              신장투석기에 의존
# 13752       Z99      Z993                휠체어에 의존
# 13753       Z99      Z998     기타 기능성 기계 및 장치에 의존
# 13754       Z99      Z999  상세불명의 기능성 기계 및 장치에 의존
#
#                                            sick_desc_eng  gender  age_limit_u  \
# 13750                           Dependence on respirator     NaN          NaN
# 13751                       Dependence on renal dialysis     NaN          NaN
# 13752                           Dependence on wheelchair     NaN          NaN
# 13753  Dependence on other enabling machines and devices     NaN          NaN
# 13754  Dependence on unspecified enabling machine and...     NaN          NaN
#
#        age_limit_l
# 13750          NaN
# 13751          NaN
# 13752          NaN
# 13753          NaN
# 13754          NaN

# %%
df_raw1.isnull().sum()
# Out:
# sick_cd_3            0
# sick_cd_4         1938
# sick_desc_kor        0
# sick_desc_eng        0
# gender           12770
# age_limit_u      13220
# age_limit_l      13204
# dtype: int64

# %%
df_raw1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13755 entries, 0 to 13754
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sick_cd_3      13755 non-null  object
#  1   sick_cd_4      11817 non-null  object
#  2   sick_desc_kor  13755 non-null  object
#  3   sick_desc_eng  13755 non-null  object
#  4   gender         985 non-null    float64
#  5   age_limit_u    535 non-null    float64
#  6   age_limit_l    551 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 752.4+ KB

# %%
df_raw1["sick_desc_kor"][0:300].value()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-068b757d3480> in <module>
# ----> 1 df_raw1["sick_desc_kor"][0:300].value()
#       2
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
len(df_raw1["sick_desc_eng"])
# Out:
# 13755

# %% [markdown]
# # insu_pre_review

# %%
df_raw2 = pd.read_csv("insu_pre_review.csv", engine = "python", encoding="CP949")
df_raw2.head()
# Out:
#   customer_id review_cat judge review_date  gender  age  height  weight  \
# 0     C112346       혈액검사    재검  2014-10-09       1   70     165      63
# 1     C112350       일반검진    재검  2014-11-18       1   69     178      75
# 2     C112355       일반검진    재검  2015-03-18       1   70     169      69
# 3     C112356       혈액검사    재검  2015-09-28       1   70     165      64
# 4     C112358       혈액검사    거절  2015-02-24       1   70     166      73
#
#     bust  waist  ...  bt_mch_judge  bt_mchc_judge  bt_mvc_judge  \
# 0   92.0   88.0  ...           0.0            0.0           0.0
# 1   99.0   92.0  ...           NaN            NaN           NaN
# 2   96.0   88.0  ...           NaN            NaN           NaN
# 3  103.0   92.0  ...           0.0            0.0           0.0
# 4  100.0   91.0  ...           0.0            0.0           0.0
#
#    bt_plat_judge  bt_rbc_judge  bt_wbc_judge  bt_rgpt_judge bt_sgot_judge  \
# ...

# %%
df_raw2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14938 entries, 0 to 14937
# Data columns (total 48 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        14938 non-null  object
#  1   review_cat         14938 non-null  object
#  2   judge              14938 non-null  object
#  3   review_date        14938 non-null  object
#  4   gender             14938 non-null  int64
#  5   age                14938 non-null  int64
#  6   height             14938 non-null  int64
#  7   weight             14938 non-null  int64
#  8   bust               14936 non-null  float64
#  9   waist              14936 non-null  float64
#  10  bp_min             14938 non-null  int64
#  11  bp_max             14938 non-null  int64
#  12  pulse_count        14934 non-null  float64
#  13  bt_chol            11781 non-null  float64
#  14  bt_crea            5751 non-null   float64
#  15  bt_gluc            11781 non-null  float64
# ...

# %%
len(df_raw2["customer_id"].unique())
# 아이디는 전부 unique (겹치는 사람 없음)
# Out:
# 14938

# %%
df_raw2.iloc[212]
# 일반검진이면, bt_어쩌구가 전부 NaN값
# 혈액이면, 뭔가 나오거나 근데 0인게 대부분
# Out:
# customer_id             C112692
# review_cat                 일반검진
# judge                        재검
# review_date          2015-04-29
# gender                        1
# age                          65
# height                      170
# weight                       62
# bust                         94
# waist                        83
# bp_min                       80
# bp_max                      135
# pulse_count                  68
# bt_chol                     NaN
# bt_crea                     NaN
# bt_gluc                     NaN
# bt_hb                       NaN
# bt_hbsa                     NaN
# bt_hct                      NaN
# bt_mch                      NaN
# bt_mchc                     NaN
# bt_mvc                      NaN
# bt_plat                     NaN
# bt_rbc                      NaN
# bt_wbc                      NaN
# bt_rgpt                     NaN
# bt_sgot                     NaN
# bt_sgpt                     NaN
# bt_trig                     NaN
# ...

# %%
df_raw2.iloc[777]
# 일반검진이면, bt_어쩌구가 전부 NaN값
# 혈액이면, 뭔가 나오거나 근데 0인게 대부분
# Out:
# customer_id             C113553
# review_cat                 혈액검사
# judge                        재검
# review_date          2015-03-25
# gender                        1
# age                          60
# height                      171
# weight                       73
# bust                         93
# waist                        80
# bp_min                       80
# bp_max                      120
# pulse_count                  62
# bt_chol                     261
# bt_crea                     NaN
# bt_gluc                      90
# bt_hb                       NaN
# bt_hbsa                NEGATIVE
# bt_hct                      NaN
# bt_mch                      NaN
# bt_mchc                     NaN
# bt_mvc                      NaN
# bt_plat                     NaN
# bt_rbc                      NaN
# bt_wbc                      NaN
# bt_rgpt                      49
# bt_sgot                      27
# bt_sgpt                      32
# bt_trig                     148
# ...

# %%
df_raw2["bt_chol_judge"].unique()
# Out:
# array([ 0., nan,  1.])

# %%
df_raw3 = pd.read_csv("insu_request.csv", engine = "python", encoding="CP949")
df_raw3.head()
# Out:
#   customer_id review_cat judge  gender  age    insu_id insu_contract_date  \
# 0     C112379       혈액검사    재검       1   69  INS-10484          08-Dec-14
# 1     C112379       혈액검사    재검       1   69  INS-10484          08-Dec-14
# 2     C112379       혈액검사    재검       1   69  INS-10484          08-Dec-14
# 3     C112379       혈액검사    재검       1   69  INS-10484          08-Dec-14
# 4     C112379       혈액검사    재검       1   69  INS-10484          08-Dec-14
#
#   insu_prod_id insu_prod_name                         req_id  ...  sick_3rd  \
# 0     PR-20363     가족 만족 보험 1  C112379-20101118-12660-01-001  ...       NaN
# 1     PR-20363     가족 만족 보험 1  C112379-20110314-17403-01-001  ...       NaN
# 2     PR-20363     가족 만족 보험 1  C112379-20110314-17403-01-001  ...       NaN
# 3     PR-20363     가족 만족 보험 1  C112379-20110314-17403-01-001  ...       NaN
# 4     PR-20363     가족 만족 보험 1  C112379-20110314-17403-01-001  ...       NaN
#
# ...

# %%
df_raw3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49449 entries, 0 to 49448
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         49449 non-null  object
#  1   review_cat          49449 non-null  object
#  2   judge               49449 non-null  object
#  3   gender              49449 non-null  int64
#  4   age                 49449 non-null  int64
#  5   insu_id             49449 non-null  object
#  6   insu_contract_date  49449 non-null  object
#  7   insu_prod_id        49449 non-null  object
#  8   insu_prod_name      49449 non-null  object
#  9   req_id              49449 non-null  object
#  10  req_id_seq          49449 non-null  int64
#  11  sick_main           49449 non-null  object
#  12  sick_1st            49449 non-null  object
#  13  sick_2nd            11500 non-null  object
#  14  sick_3rd            4844 non-null   object
# ...

# %%
(df_raw3["insu_pay_amount"] == 0).value_counts()
# 지급액이 0인 사람은 없다.
# Out:
# False    49449
# Name: insu_pay_amount, dtype: int64

# %%
(df_raw3["insu_req_amount"] == 0).value_counts()
# 고객이 청구를 안 해도, 보험사에서 알아서 지급되는 금액이 있다.(True값)
# Out:
# False    37795
# True     11654
# Name: insu_req_amount, dtype: int64

# %%
df_raw3.query(df_raw3["insu_req_amount"] < df_raw3["insu_pay_amount"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-081771032bfb> in <module>
# ----> 1 df_raw3.query(df_raw3["insu_req_amount"] < df_raw3["insu_pay_amount"])
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    3226         if not isinstance(expr, str):
#    3227             msg = f"expr must be a string to be evaluated, {type(expr)} given"
# -> 3228             raise ValueError(msg)
#    3229         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3230         kwargs["target"] = None
#
# ValueError: expr must be a string to be evaluated, <class 'pandas.core.series.Series'> given
