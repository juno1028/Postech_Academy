# %% [markdown]
# ## 분석배경
# : OO공장의 고객사에서 최근 들어 "Scale 불량 발생 증가"라는 이슈가 발생했다. 그 원인을 분석해 본 결과 압연공정에서 Scale불량이 급증한 것을 확인할 수 있었다. 그래서 데이터를 수집하여 다양한 분석을 통해 불량 발생의 근본 원인을 찾고 결과를 해석하여 개선 기회를 도출한다.

# %% [markdown]
# ## 잠재적인 인자 선정
#
# * Scale 발생 : `없음 - 발생`
#     1. 가열로 가열대 온도(FUR_HZ_TEMP) : `저 - 고`
#     2. 가열로 균열대 온도(FUR_SZ_TEMP) : `저 - 고`
#     3. 가열로 추출 온도(FUR_EXTEMP) : `저 - 고`
#     4. Hot Scale Breaker(HSB) : `적용 - 미적용`
#     5. 사상 압연 온도(ROLLING_TEMP_T5) : `저 - 고`
#     6. 압연간 Descaling 횟수(ROLLING_DESCALING) : `증가 - 감소`
#     7. 판두께(PT_THICK) : `후 - 박`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

import seaborn as sns

matplotlib.rc('font', family='NanumGothic')

# %matplotlib inline

# %% [markdown]
# ## 데이터 불러오기 및 확인

# %%
df_raw = pd.read_csv("~/Desktop/coding/postech/Postech_Academy/Practice/data/SCALE불량.csv", engine="python",encoding="EUC-KR")
df_raw.head()
# Out:
#    PLATE_NO         ROLLING_DATE SCALE        SPEC STEEL_KIND  PT_THK  \
# 0  PB562774  2008-08-01:00:00:15    양품  AB/EH32-TM         T1   32.25
# 1  PB562775  2008-08-01:00:00:16    양품  AB/EH32-TM         T1   32.25
# 2  PB562776  2008-08-01:00:00:59    양품   NV-E36-TM         T8   33.27
# 3  PB562777  2008-08-01:00:01:24    양품   NV-E36-TM         T8   33.27
# 4  PB562778  2008-08-01:00:01:44    양품  BV-EH36-TM         T8   38.33
#
#    PT_WDTH  PT_LTH  PT_WGT FUR_NO  ...  FUR_HZ_TEMP  FUR_HZ_TIME  FUR_SZ_TEMP  \
# 0     3707   15109   14180    1호기  ...         1144          116         1133
# 1     3707   15109   14180    1호기  ...         1144          122         1135
# 2     3619   19181   18130    2호기  ...         1129          116         1121
# 3     3619   19181   18130    2호기  ...         1152          125         1127
# 4     3098   13334   12430    3호기  ...         1140          134         1128
#
#    FUR_SZ_TIME  FUR_TIME  FUR_EXTEMP  ROLLING_TEMP_T5  HSB ROLLING_DESCALING  \
# 0           59       282        1133              934   적용                 8
# 1           53       283        1135              937   적용                 8
# 2           55       282        1121              889   적용                 8
# 3           68       316        1127              885   적용                 8
# 4           48       314        1128              873   적용                 8
#
#    WORK_GR
# 0       2조
# 1       2조
# 2       3조
# 3       3조
# 4       1조
#
# [5 rows x 21 columns]

# %%
#결측지 확인
df_raw.isnull().sum(axis=0)
# Out:
# PLATE_NO             0
# ROLLING_DATE         0
# SCALE                0
# SPEC                 0
# STEEL_KIND           0
# PT_THK               0
# PT_WDTH              0
# PT_LTH               0
# PT_WGT               0
# FUR_NO               0
# FUR_NO_ROW           0
# FUR_HZ_TEMP          0
# FUR_HZ_TIME          0
# FUR_SZ_TEMP          0
# FUR_SZ_TIME          0
# FUR_TIME             0
# FUR_EXTEMP           0
# ROLLING_TEMP_T5      0
# HSB                  0
# ROLLING_DESCALING    0
# WORK_GR              0
# dtype: int64

# %% [markdown]
# : 결측치가 없는 것을 확인할 수 있다.

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLATE_NO           720 non-null    object
#  1   ROLLING_DATE       720 non-null    object
#  2   SCALE              720 non-null    object
#  3   SPEC               720 non-null    object
#  4   STEEL_KIND         720 non-null    object
#  5   PT_THK             720 non-null    float64
#  6   PT_WDTH            720 non-null    int64
#  7   PT_LTH             720 non-null    int64
#  8   PT_WGT             720 non-null    int64
#  9   FUR_NO             720 non-null    object
#  10  FUR_NO_ROW         720 non-null    int64
#  11  FUR_HZ_TEMP        720 non-null    int64
#  12  FUR_HZ_TIME        720 non-null    int64
#  13  FUR_SZ_TEMP        720 non-null    int64
#  14  FUR_SZ_TIME        720 non-null    int64
#  15  FUR_TIME           720 non-null    int64
#  16  FUR_EXTEMP         720 non-null    int64
#  17  ROLLING_TEMP_T5    720 non-null    int64
#  18  HSB                720 non-null    object
#  19  ROLLING_DESCALING  720 non-null    int64
#  20  WORK_GR            720 non-null    object
# dtypes: float64(1), int64(12), object(8)
# memory usage: 118.2+ KB

# %%
len(list(df_raw["SPEC"].unique()))
# Out:
# 66

# %% [markdown]
# : 66 종류의 제품 규격이 존재한다.

# %% [markdown]
# # 1. 탐색적 기법

# %% [markdown]
# ## 1.1 그래프

# %%
def fun_plot_hist(data, var):
    plt.hist(data[data["SCALE"] == "양품"][var], label = "양품", alpha = 0.5)
    plt.hist(data[data["SCALE"] == "불량"][var], label = "불량", alpha = 0.5)

# %%
def fun_plot_bar(data, var):
    plt.bar(data[data["SCALE"] == "양품"][var], label = "양품", alpha = 0.5)
    plt.bar(data[data["SCALE"] == "불량"][var], label = "불량", alpha = 0.5)

# %%
def fun_print_crosstab(data, var):
    print(pd.crosstab(index = data["SCALE"], columns = data[var]))
    print()
    print(pd.crosstab(index = data["SCALE"], columns = data[var], normalize = "columns").round(3))

# %%
def aggregate(rows,columns,df):
    column_keys = df[columns].unique()
    row_keys = df[rows].unique()

    agg = { key : [ len(df[(df[rows]==value) & (df[columns]==key)]) for value in row_keys]
               for key in column_keys }

    aggdf = pd.DataFrame(agg,index = row_keys)
    aggdf.index.rename(rows,inplace=True)

    return aggdf

# %% [markdown]
# * 잠재적인 인자로 추정되는 것들을 먼저 히스토그램을 통해 확인해본다.

# %%
# 1. 가열로 가열대 온도(FUR_HZ_TEMP) : `저 - 고`
fun_plot_hist(df_raw, "FUR_HZ_TEMP")

# %% [markdown]
# : 추정된 것과 유사한 상관관계를 시각적으로 확인할 수 있다.

# %%
# 2. 가열로 균열대 온도(FUR_SZ_TEMP) : `저 - 고`
fun_plot_hist(df_raw, "FUR_SZ_TEMP")

# %% [markdown]
# : 추정된 것과 유사한 상관관계를 시각적으로 확인할 수 있다.

# %%
# 3. 가열로 추출 온도(FUR_EXTEMP) : `저 - 고`
fun_plot_hist(df_raw, "FUR_EXTEMP")

# %% [markdown]
# : 추정된 것과 유사한 상관관계를 시각적으로 확인할 수 있다.

# %%
# 4. Hot Scale Breaker(HSB) : `적용 - 미적용`
aggregate('HSB', 'SCALE', df_raw).plot(kind='bar',stacked=True)

# %% [markdown]
# : 'HSB'는 범주형 변수이기에 bar_plot으로 나타냈다. 그 결과, 미적용 한 것의 불량률이 높은 것을 직접 확인할 수 있었다.

# %%
# 5. 사상 압연 온도(ROLLING_TEMP_T5) : `저 - 고`
fun_plot_hist(df_raw, "ROLLING_TEMP_T5")

# %% [markdown]
# : 사상 압연 온도에서 시각적으로 가장 큰 상관관게를 확인할 수 있었다. 1000도를 기준으로 불량률이 극명하게 나타났고, 이는 후에 상관계수를 계산할 때 큰 값이 도출될 것임을 예측할 수 있었다. 또한, 이상치를 확인할 수 있었다.
#
# * 이상치라고 판단한 이유 : 자료를 조사해 본 결과, "사상압연의 경우는 일반적으로 850~870℃정도이며, 탄소량이 낮은 냉연재의 경우는 900℃ 이상에서 사상압연을 완료해야 한다."라는 내용을 확인할 수 있었다. 따라서 사상압연의 온도가 200도 보다 낮으므로 이상치로 판단할 수 있었다.

# %%
# 이상치 제거
df_raw[df_raw["ROLLING_TEMP_T5"]<200]
# Out:
#      PLATE_NO         ROLLING_DATE SCALE        SPEC STEEL_KIND  PT_THK  \
# 41   PB562815  2008-08-01:02:23:09    양품   GL-E36-TM         T8   55.51
# 184  PB562958  2008-08-01:10:00:06    양품  JS-SM490YB         C0   16.09
# 185  PB562959  2008-08-01:09:94:29    양품  JS-SM490YB         C0   16.09
# 494  PB563268  2008-08-02:01:10:40    양품  PILAC-BT33         T5   80.82
# 495  PB563269  2008-08-02:01:10:36    양품  PILAC-BT33         T5   80.82
# 496  PB563270  2008-08-02:01:10:23    양품   NV-D32-TM         T0   40.35
#
#      PT_WDTH  PT_LTH  PT_WGT FUR_NO  ...  FUR_HZ_TEMP  FUR_HZ_TIME  \
# 41      3765   11398   37400    3호기  ...         1132           95
# 184     2221   43596   61150    3호기  ...         1169           64
# 185     2221   43596   61150    3호기  ...         1163           57
# 494     2085   12919   17090    2호기  ...         1133           89
# 495     2085   13176   17430    1호기  ...         1130           92
# 496     2497   23592   37320    3호기  ...         1119          109
#
#      FUR_SZ_TEMP  FUR_SZ_TIME  FUR_TIME  FUR_EXTEMP  ROLLING_TEMP_T5  HSB  \
# 41          1128           80       341        1128                0   적용
# 184         1164           61       308        1164                0   적용
# 185         1166           67       303        1166                0   적용
# 494         1122           59       378        1122                0   적용
# 495         1124           61       362        1124                0   적용
# 496         1117           76       383        1117                0   적용
#
#     ROLLING_DESCALING  WORK_GR
# 41                  6       1조
# 184                10       3조
# 185                10       4조
# 494                 6       2조
# 495                 6       3조
# 496                 6       3조
#
# [6 rows x 21 columns]

# %%
df_raw = df_raw.drop([41,184,185,494,495,496])
df_raw.reset_index(drop=True, inplace=True)
df_raw
# Out:
#      PLATE_NO         ROLLING_DATE SCALE        SPEC STEEL_KIND  PT_THK  \
# 0    PB562774  2008-08-01:00:00:15    양품  AB/EH32-TM         T1   32.25
# 1    PB562775  2008-08-01:00:00:16    양품  AB/EH32-TM         T1   32.25
# 2    PB562776  2008-08-01:00:00:59    양품   NV-E36-TM         T8   33.27
# 3    PB562777  2008-08-01:00:01:24    양품   NV-E36-TM         T8   33.27
# 4    PB562778  2008-08-01:00:01:44    양품  BV-EH36-TM         T8   38.33
# ..        ...                  ...   ...         ...        ...     ...
# 709  PB563502  2008-08-02:13:35:36    불량       NK-KA         C0   20.14
# 710  PB563503  2008-08-02:13:35:02    양품      NV-A32         C0   15.08
# 711  PB563504  2008-08-02:14:40:00    양품      NV-A32         C0   16.60
# 712  PB563505  2008-08-02:13:35:19    양품        LR-A         C0   15.59
# 713  PB563506  2008-08-02:14:40:53    양품      GL-A32         C0   16.09
#
#      PT_WDTH  PT_LTH  PT_WGT FUR_NO  ...  FUR_HZ_TEMP  FUR_HZ_TIME  \
# 0       3707   15109   14180    1호기  ...         1144          116
# 1       3707   15109   14180    1호기  ...         1144          122
# 2       3619   19181   18130    2호기  ...         1129          116
# 3       3619   19181   18130    2호기  ...         1152          125
# 4       3098   13334   12430    3호기  ...         1140          134
# ..       ...     ...     ...    ...  ...          ...          ...
# 709     3580   38639   21870    3호기  ...         1172           72
# 710     3212   48233   18340    2호기  ...         1150           61
# 711     3441   43688   19590    2호기  ...         1169           65
# 712     3363   48740   80240    3호기  ...         1179           86
# 713     3400   54209   69840    3호기  ...         1186           82
#
#      FUR_SZ_TEMP  FUR_SZ_TIME  FUR_TIME  FUR_EXTEMP  ROLLING_TEMP_T5  HSB  \
# 0           1133           59       282        1133              934   적용
# 1           1135           53       283        1135              937   적용
# 2           1121           55       282        1121              889   적용
# 3           1127           68       316        1127              885   적용
# 4           1128           48       314        1128              873   적용
# ..           ...          ...       ...         ...              ...  ...
# 709         1164           62       245        1164             1005   적용
# 710         1169           61       238        1169              947   적용
# 711         1163           77       247        1163              948   적용
# 712         1163           45       243        1163              940   적용
# 713         1169           45       239        1169              957   적용
#
#     ROLLING_DESCALING  WORK_GR
# 0                   8       2조
# 1                   8       2조
# 2                   8       3조
# 3                   8       3조
# 4                   8       1조
# ..                ...      ...
# 709                 8       2조
# 710                10       1조
# 711                10       4조
# 712                10       2조
# 713                10       2조
#
# [714 rows x 21 columns]

# %% [markdown]
# : 이상치가 올바르게 제거된 것을 확인할 수 있다.

# %%
# 6. 압연간 Descaling 횟수(ROLLING_DESCALING) : `증가 - 감소`
fun_plot_hist(df_raw, "ROLLING_DESCALING")

# %% [markdown]
# : 압연간 Descaling 횟수가 5,7,8,9회 일 때의 불량률이 높았다. 이는 잠재적인 인자로 추정한 내용과는 차이가 있는 내용이고, 이에 대해 추가적인 판단이 필요할 것으로 보인다.

# %%
# 7. 판두께(PT_THICK) : `후 - 박`
fun_plot_hist(df_raw, "PT_THK")

# %% [markdown]
# : 잠재적인 인자로 추정했던 판 두께가 실제로 상관관계를 보이는 것을 시작적으로 확인할 수 있다. 판이 얇을수록 불량률이 높았고, 판이 두꺼울수록 불량률이 낮아지는 것을 확인할 수 있었다.

# %% [markdown]
# # 잠재적인 인자외에 다른 것도 추가하기 ----------------(강종, Plate폭, 길이, 중량, 가열로 호기, 가열로 작업순번, 가열대 시간, 균열대 시간, 가열로 시간, 작업조)

# %%
sns.pairplot(df_raw)

# %% [markdown]
# # 2. 데이터 전처리

# %% [markdown]
# ## 2.1 설명변수와 목표변수 분리

# %%
df_raw_x = df_raw.drop("SCALE", axis=1, inplace=False)
df_raw_y = df_raw["SCALE"]

# %% [markdown]
# ## 2.2 설명변수에서 필요없는 변수 제거
#
# : `PLATE_NO`와 `ROLLING_DATE` Column은 분석을 할 때 아무 의미를 가지지 않으므로 제거한다.

# %%
df_raw_x = df_raw_x.drop(["PLATE_NO","ROLLING_DATE"],axis=1, inplace=False)

# %%
df_raw_x
# Out:
#            SPEC STEEL_KIND  PT_THK  PT_WDTH  PT_LTH  PT_WGT FUR_NO  \
# 0    AB/EH32-TM         T1   32.25     3707   15109   14180    1호기
# 1    AB/EH32-TM         T1   32.25     3707   15109   14180    1호기
# 2     NV-E36-TM         T8   33.27     3619   19181   18130    2호기
# 3     NV-E36-TM         T8   33.27     3619   19181   18130    2호기
# 4    BV-EH36-TM         T8   38.33     3098   13334   12430    3호기
# ..          ...        ...     ...      ...     ...     ...    ...
# 709       NK-KA         C0   20.14     3580   38639   21870    3호기
# 710      NV-A32         C0   15.08     3212   48233   18340    2호기
# 711      NV-A32         C0   16.60     3441   43688   19590    2호기
# 712        LR-A         C0   15.59     3363   48740   80240    3호기
# 713      GL-A32         C0   16.09     3400   54209   69840    3호기
#
#      FUR_NO_ROW  FUR_HZ_TEMP  FUR_HZ_TIME  FUR_SZ_TEMP  FUR_SZ_TIME  FUR_TIME  \
# 0             1         1144          116         1133           59       282
# 1             2         1144          122         1135           53       283
# 2             1         1129          116         1121           55       282
# 3             2         1152          125         1127           68       316
# 4             1         1140          134         1128           48       314
# ..          ...          ...          ...          ...          ...       ...
# 709           1         1172           72         1164           62       245
# 710           1         1150           61         1169           61       238
# 711           2         1169           65         1163           77       247
# 712           2         1179           86         1163           45       243
# 713           1         1186           82         1169           45       239
#
#      FUR_EXTEMP  ROLLING_TEMP_T5 HSB  ROLLING_DESCALING WORK_GR
# 0          1133              934  적용                  8      2조
# 1          1135              937  적용                  8      2조
# 2          1121              889  적용                  8      3조
# 3          1127              885  적용                  8      3조
# 4          1128              873  적용                  8      1조
# ..          ...              ...  ..                ...     ...
# 709        1164             1005  적용                  8      2조
# 710        1169              947  적용                 10      1조
# 711        1163              948  적용                 10      4조
# 712        1163              940  적용                 10      2조
# 713        1169              957  적용                 10      2조
#
# [714 rows x 18 columns]

# %% [markdown]
# : 2개의 Column이 정상적으로 삭제되었다.

# %% [markdown]
# ## 2.3 HSB, SCALE 범주형 변수로 변환 0,1로

# %%
# 설명변수 중 SCALE 범주형 변수로 바꾸기
df_raw_x['HSB'] = df_raw_x['HSB'].replace("미적용", 0)
df_raw_x['HSB'] = df_raw_x['HSB'].replace("적용", 1)

# %%
# 목표변수 범주형 변수로 바꾸기
df_raw_y = df_raw_y.replace("양품", 0)
df_raw_y = df_raw_y.replace("불량", 1)

# %%
df_raw_y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 709    1
# 710    0
# 711    0
# 712    0
# 713    0
# Name: SCALE, Length: 714, dtype: int64

# %%
# HSB, SCALE int -> object로 타입 바꾸기
df_raw_x = df_raw_x.astype({'HSB':'object'})
df_raw_y = df_raw_y.astype('object')

# %%
df_raw_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SPEC               714 non-null    object
#  1   STEEL_KIND         714 non-null    object
#  2   PT_THK             714 non-null    float64
#  3   PT_WDTH            714 non-null    int64
#  4   PT_LTH             714 non-null    int64
#  5   PT_WGT             714 non-null    int64
#  6   FUR_NO             714 non-null    object
#  7   FUR_NO_ROW         714 non-null    int64
#  8   FUR_HZ_TEMP        714 non-null    int64
#  9   FUR_HZ_TIME        714 non-null    int64
#  10  FUR_SZ_TEMP        714 non-null    int64
#  11  FUR_SZ_TIME        714 non-null    int64
#  12  FUR_TIME           714 non-null    int64
#  13  FUR_EXTEMP         714 non-null    int64
#  14  ROLLING_TEMP_T5    714 non-null    int64
#  15  HSB                714 non-null    object
#  16  ROLLING_DESCALING  714 non-null    int64
#  17  WORK_GR            714 non-null    object
# dtypes: float64(1), int64(12), object(5)
# memory usage: 100.5+ KB

# %%
df_raw_y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 709    1
# 710    0
# 711    0
# 712    0
# 713    0
# Name: SCALE, Length: 714, dtype: object

# %% [markdown]
# : `df_raw_x["HSB"]`와 `df_raw_y` 모두 0,1의 object 형식으로 올바르게 변환된 것을 확인할 수 있다.

# %% [markdown]
# ## 2.4 df_train, df_valid, df_test 로 분리
#
# : 모델 학습 및 평가를 위하여 데이터를 분리하는 작업을 진행한다. (7:3:3의 비율로 분할한다.)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from statsmodels.api import Logit
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
df_train, df_test = train_test_split(df_raw,
                                    test_size=0.3,
                                    random_state=1234)

df_train, df_valid = train_test_split(df_train,
                                    test_size=3/7,
                                    random_state=1234)

print("train data size : {}".format(df_train.shape))
print("valid data size : {}".format(df_valid.shape))
print("test data size : {}".format(df_test.shape))
# Out:
# train data size : (285, 21)
# valid data size : (214, 21)
# test data size : (215, 21)

# %% [markdown]
# # 3. 검정

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLATE_NO           714 non-null    object
#  1   ROLLING_DATE       714 non-null    object
#  2   SCALE              714 non-null    object
#  3   SPEC               714 non-null    object
#  4   STEEL_KIND         714 non-null    object
#  5   PT_THK             714 non-null    float64
#  6   PT_WDTH            714 non-null    int64
#  7   PT_LTH             714 non-null    int64
#  8   PT_WGT             714 non-null    int64
#  9   FUR_NO             714 non-null    object
#  10  FUR_NO_ROW         714 non-null    int64
#  11  FUR_HZ_TEMP        714 non-null    int64
#  12  FUR_HZ_TIME        714 non-null    int64
#  13  FUR_SZ_TEMP        714 non-null    int64
#  14  FUR_SZ_TIME        714 non-null    int64
#  15  FUR_TIME           714 non-null    int64
#  16  FUR_EXTEMP         714 non-null    int64
#  17  ROLLING_TEMP_T5    714 non-null    int64
#  18  HSB                714 non-null    object
#  19  ROLLING_DESCALING  714 non-null    int64
#  20  WORK_GR            714 non-null    object
# dtypes: float64(1), int64(12), object(8)
# memory usage: 117.3+ KB

# %%
df_train
# Out:
#      PLATE_NO         ROLLING_DATE SCALE        SPEC STEEL_KIND  PT_THK  \
# 636  PB563429  2008-08-02:10:05:55    양품      NV-A32         C0   19.13
# 597  PB563377  2008-08-02:09:92:41    불량     SA283-C         C0   20.18
# 173  PB562948  2008-08-01:09:91:42    불량  JS-SM490YB         C0   20.10
# 696  PB563489  2008-08-02:13:31:03    양품     LR-AH32         C0   12.05
# 130  PB562905  2008-08-01:07:72:46    불량   JS-SM400B         C0   18.10
# ..        ...                  ...   ...         ...        ...     ...
# 37   PB562811  2008-08-01:02:21:17    양품  AB/EH36-TM         T8   51.27
# 525  PB563305  2008-08-02:06:60:22    양품        NV-A         C0   12.56
# 590  PB563370  2008-08-02:08:85:41    양품       NK-KA         C0   13.06
# 555  PB563335  2008-08-02:07:72:44    불량        KR-A         C0   22.66
# 264  PB563041  2008-08-01:13:30:10    양품      NV-A32         C0   17.10
#
#      PT_WDTH  PT_LTH  PT_WGT FUR_NO  ...  FUR_HZ_TEMP  FUR_HZ_TIME  \
# 636     2733   49754   20420    1호기  ...         1164           72
# 597     2281   43144   77950    3호기  ...         1159           66
# 173     2232   43728   77000    1호기  ...         1169           77
# 696     2855   52321   28260    1호기  ...         1159           54
# 130     2520   42675   61120    3호기  ...         1167          130
# ..       ...     ...     ...    ...  ...          ...          ...
# 37      3060   12407   15280    1호기  ...         1122           57
# 525     3210   42686   13510    3호기  ...         1160          153
# 590     2750   54906   61920    2호기  ...         1167           66
# 555     2513   46374   82920    3호기  ...         1163          229
# 264     3103   49216   41000    3호기  ...         1126           74
#
#      FUR_SZ_TEMP  FUR_SZ_TIME  FUR_TIME  FUR_EXTEMP  ROLLING_TEMP_T5  HSB  \
# 636         1158           60       255        1158              961   적용
# 597         1155           80       342        1155             1002   적용
# 173         1165           73       314        1165             1031   적용
# 696         1156           74       252        1156              894   적용
# 130         1166           63       319        1166             1012   적용
# ..           ...          ...       ...         ...              ...  ...
# 37          1123          105       337        1123              862   적용
# 525         1138          212       342        1138              906   적용
# 590         1158           84       342        1158              933   적용
# 555         1158           60       342        1158             1028   적용
# 264         1147           55       265        1147              939   적용
#
#     ROLLING_DESCALING  WORK_GR
# 636                10       2조
# 597                 8       4조
# 173                 8       4조
# 696                10       3조
# 130                10       3조
# ..                ...      ...
# 37                  6       4조
# 525                10       4조
# 590                10       2조
# 555                 8       4조
# 264                10       4조
#
# [285 rows x 21 columns]

# %%
log_model = Logit.from_formula("""SCALE ~ C(STEEL_KIND) + PT_THK + PT_WDTH + PT_LTH + PT_WGT + C(FUR_NO) + FUR_NO_ROW + FUR_HZ_TEMP + FUR_HZ_TIME + FUR_SZ_TEMP + FUR_SZ_TIME + FUR_TIME + FUR_EXTEMP + ROLLING_TEMP_T5 + C(HSB) + ROLLING_DESCALING + C(WORK_GR)""", df_raw_x)

log_result = log_model.fit()
print(log_result.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-157-38994b95e0b8> in <module>
# ----> 1 log_model = Logit.from_formula("""SCALE ~ C(STEEL_KIND) + PT_THK + PT_WDTH + PT_LTH + PT_WGT + C(FUR_NO) + FUR_NO_ROW + FUR_HZ_TEMP + FUR_HZ_TIME + FUR_SZ_TEMP + FUR_SZ_TIME + FUR_TIME + FUR_EXTEMP + ROLLING_TEMP_T5 + C(HSB) + ROLLING_DESCALING + C(WORK_GR)""", df_raw_x)
#       2
#       3 log_result = log_model.fit()
#       4 print(log_result.summary())
#
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     172         if (max_endog is not None and
#     173                 endog.ndim > 1 and endog.shape[1] > max_endog):
# --> 174             raise ValueError('endog has evaluated to an array with multiple '
#     175                              'columns that has shape {0}. This occurs when '
#     176                              'the variable converted to endog is non-numeric'
#
# ValueError: endog has evaluated to an array with multiple columns that has shape (714, 2). This occurs when the variable converted to endog is non-numeric (e.g., bool or str).
